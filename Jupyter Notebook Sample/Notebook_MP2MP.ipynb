# %% [markdown]
# # Bloonet Jupyter Notebook

# %% [markdown]
# ## Required imports

# %%
import requests
import uuid
import json
import time
import shutil
import pandas as pd
import numpy as np
import io
import asyncio
import re
import ipywidgets as widgets
from IPython.display import display
from typing import Union
from pathlib import Path
from shapely.geometry import Polygon, Point
from pyproj import Geod

# %% [markdown]
# ## Required constants
# Update your authentication information before running a calculation.

# %%
SESSION_UUID = None
SIMULATION_UUID = None
BWS_API_URL = "https://api.bloonetws.siradel.com"
BWS_DL_URL = "https://dl.bloonetws.siradel.com"
NOMINATIM_URL = "https://nominatim.openstreetmap.org/search"
RECEPTION_HEIGHT = 2
RESOLUTION = 10
RECEIVER_BUFFER_RADIUS_M = 60000
ACCESS_TOKEN = None
REFRESH_TOKEN = None
AUTHENTICATION = {
    "url": "https://keycloak.bloonetws.siradel.com/realms/volcanoweb/protocol/openid-connect/token",
    "clientId": "volcano-web-cli",
    "username": "USERNAME",
    "password": "PASSWORD"
}

# %% [markdown]
# ## Required functions

# %%
def call_request(method: str, url: str, authentication_data: dict,
                 files: list = None, json_content: Union[dict, list] = None,
                 params: dict = None, retry: int = 0, timeout=None) -> requests.Response:
    """
    Call requests with args for use authenticate

    @param method: {str} method request
    @param url: {str} url request
    @param authentication_data: {dict} authentication data
    @param files: {list} files request
    @param json_content: {dict} json request
    @param params: {dict} params request
    @param retry: {int} number of retry
    @param timeout: {Any} timeout request

    @return: {request.Response} response of request
    """

    headers = None

    if authentication_data is None:
        print("Authentication data needed")
    token = get_access_token(authentication_data)
    headers = {"Authorization": f"Bearer {token}"}

    res = None
    if method.upper() == "POST":
        res = requests.post(url=url, files=files, json=json_content, params=params,
                            timeout=timeout, headers=headers)
    elif method.upper() == "PUT":
        res = requests.put(url=url, files=files, json=json_content, params=params,
                           timeout=timeout, headers=headers)
    elif method.upper() == "GET":
        res = requests.get(url=url, files=files, json=json_content, params=params,
                           timeout=timeout, headers=headers)
    elif method.upper() == "DELETE":
        res = requests.delete(url=url, files=files, json=json_content, params=params,
                              timeout=timeout, headers=headers)
    else:
        raise ValueError("Method name %S not implemented", method.upper())

    # If access_token expires, refresh the token one time and recall requests
    if res.status_code == 403 and retry == 0:
        refresh_token(authentication_data)
        res = call_request(
            method,
            url,
            authentication_data,
            files,
            json_content,
            params,
            1,
            timeout
        )

    return res


def get_access_token(authentication_data: dict) -> str:
    """
    Retrieve an access token

    @param authentication_data: {dict} authentication data

    @return: {str} access token provided
    """

    global ACCESS_TOKEN, REFRESH_TOKEN
    if ACCESS_TOKEN is not None:
        return ACCESS_TOKEN
    payload = {
        "grant_type": "password",
        "client_id": authentication_data["clientId"],
        "username": authentication_data["username"],
        "password": authentication_data["password"]
    }

    response = requests.post(
        authentication_data["url"],
        data=payload
    )

    json_response = response.json()

    if response.status_code == 200:
        ACCESS_TOKEN = json_response["access_token"]
        REFRESH_TOKEN = json_response["refresh_token"]
    else:
        raise RuntimeError("Error call get access token: %s", json_response["error_description"])
    return ACCESS_TOKEN


def refresh_token(authentication_data: dict) -> None:
    """
    Refresh the access token

    @param authentication_data: {dict} authentication data
    """

    global ACCESS_TOKEN, REFRESH_TOKEN
    if REFRESH_TOKEN is None:
        raise RuntimeError("Error call refresh token : refresh token is empty")

    payload = {
        "grant_type": "refresh_token",
        "client_id": authentication_data["clientId"],
        "refresh_token": REFRESH_TOKEN
    }

    response = requests.post(
        authentication_data["url"],
        data=payload
    )

    json_response = response.json()

    if response.status_code == 200:
        ACCESS_TOKEN = json_response["access_token"]
        REFRESH_TOKEN = json_response["refresh_token"]
    else:
        raise RuntimeError("Error call get refresh token: %s", json_response["error_description"])


def is_same_base_station(base_station_1: dict, base_station_2: dict) -> bool:
    """
    Check if the two base stations in parameter are the same

    @param base_station_1: {dict} first base station to compare
    @param base_station_2: {dict} second base station to compare

    @return: {bool} True if equals, False else
    """
    return (
            base_station_1["networkId"] == base_station_2["networkId"] and
            base_station_1["name"] == base_station_2["name"] and
            base_station_1["x"] == base_station_2["x"] and
            base_station_1["y"] == base_station_2["y"] and
            base_station_1["z"] == base_station_2["z"] and
            base_station_1["azimuth"] == base_station_2["azimuth"] and
            base_station_1["downtilt"] == base_station_2["downtilt"] and
            base_station_1["carrierFrequency"] == base_station_2["carrierFrequency"] and
            base_station_1["transmitPower"] == base_station_2["transmitPower"]
    )


def extract_rows_from_json(obj: dict, metric_name: str) -> list: 
    """
    Extract transmitter-receiver metric rows from a JSON object.

    @param obj: {dict} JSON-like object representing simulation results, expected to contain
        a "transmitters" key with nested receiver data.
    @param metric_name: {str} Name of the metric to extract from receiver qualifications
        (e.g., "received_power").

    @return: {list} A list of dictionaries, each with keys:
        - "receiver": Receiver name
        - "transmitter": Transmitter name
        - <metric_name>: Extracted metric value (or None if not found)
    """
    rows = []
    for tx in obj.get("transmitters", []):
        tx_name = tx.get("name")
        for rx in tx.get("receivers", []):
            rx_name = rx.get("name")
            value = None
            for q in rx.get("qualifications", []):
                if q.get("name") == metric_name:
                    value = q.get("value")
                    break
            rows.append({"receiver": rx_name, "transmitter": tx_name, metric_name: value})
    return rows


def get_public_models() -> list:
    """
    Retrieve the public models

    @return: {list} list of public models
    """
    response = call_request(
        method="GET",
        url=f"{BWS_API_URL}/propagationmodels",
        authentication_data=AUTHENTICATION
    )
    public_models_list = response.json()

    if response.status_code != 200:
        raise RuntimeError("Error call get public models: %s", public_models_list["error_description"])

    PUBLIC_MODELS_NAME = ["fixed wireless access", "mobility"]
    public_models = [model for model in public_models_list if model["name"].lower() in PUBLIC_MODELS_NAME and model["type"] is None]
    return public_models


def get_public_antennas() -> list:
    """
    Retrieve the public antennas

    @return: {list} list of public antennas
    """
    response = call_request(
        method="GET",
        url=f"{BWS_API_URL}/antennas",
        authentication_data=AUTHENTICATION
    )
    public_antennas_list = response.json()

    if response.status_code != 200:
        raise RuntimeError("Error call get public antennas: %s", public_antennas_list["error_description"])

    PUBLIC_ANTENNAS_NAME = [
        "tarana-bn-3ghz-compact-r0",
        "tarana-bn-5ghz-r1",
        "tarana-bn-6ghz-r2",
        "tarana-bn-6ghz-x2-r2"
    ]
    public_antennas = [antenna for antenna in public_antennas_list if antenna["name"].lower() in PUBLIC_ANTENNAS_NAME]
    return public_antennas

# %% [markdown]
# ## UI elements

# %%
# Display areas
out_tx = widgets.Output()
out_rx = widgets.Output()
out_model = widgets.Output()
out_antenna = widgets.Output()
out_status = widgets.Output()

# Widgets transmitters
label_tx = widgets.HTML("<b>Select how to provide transmitters:</b>")

radio_tx = widgets.RadioButtons(
    options=[
        ("Use default transmitters", "default"),
        ("Upload CSV file for the transmitters", "csv"),
    ],
    value="default",
    layout=widgets.Layout(width="auto")
)

label_csv_tx = widgets.Label("Select the CSV file for the transmitters:")
upload_tx = widgets.FileUpload(accept=".csv", multiple=False)

tx_default_container = widgets.VBox([
    out_tx
])

tx_dl_container = widgets.VBox([
    label_csv_tx,
    upload_tx,
    out_tx
])

# --- Initial visibility ---
tx_default_container.layout.display = "block"
tx_dl_container.layout.display = "none"

# Widgets receivers
label_rx = widgets.HTML("<b>Select how to provide receivers:</b>")

radio_rx = widgets.RadioButtons(
    options=[
        ("Upload CSV file for the receivers", "csv"),
        ("Enter a receiver address", "address"),
    ],
    value="csv",
    layout=widgets.Layout(width="auto")
)

label_csv_rx = widgets.Label("Select the CSV file for the receivers:")
upload_rx = widgets.FileUpload(accept=".csv", multiple=False)

label_search_rx = widgets.Label("Enter a receiver address:")
status = widgets.HTML(value="<i>Start typing to see suggestions…</i>")
search_rx = widgets.Text(
    placeholder="Enter a receiver address",
    description="Address:",
    layout=widgets.Layout(width="50%")
)

suggestions_rx = widgets.Select(
    options=[],
    rows=6,
    description="Choice:",
    layout=widgets.Layout(width="70%", display="none")
)

rx_dl_container = widgets.VBox([
    label_csv_rx,
    upload_rx,
    out_rx
])

rx_search_container = widgets.VBox([
    label_search_rx,
    search_rx,
    suggestions_rx,
    status,
    out_rx
])

# --- Initial visibility: CSV by default ---
rx_dl_container.layout.display = "block"
rx_search_container.layout.display = "none"

# Widgets model
label_model = widgets.Label("Select the propagation model to use:")
dropdown_model = widgets.Dropdown(
    options=[(m["name"], m["uuid"]) for m in get_public_models()]
)

# Widgets antenna
label_antenna = widgets.Label("Select the antenna diagram to use:")
dropdown_antenna = widgets.Dropdown(
    options=[(m["name"], m["uuid"]) for m in get_public_antennas()]
)

# Button to start the calculation
btn_run = widgets.Button(
    description="Start the calculation",
    button_style="primary",
    disabled=True
)

# Layout
ui = widgets.VBox([
    # Transmitters
    label_tx, radio_tx, tx_default_container, tx_dl_container,
    widgets.HTML("<hr>"),
    # Receivers
    label_rx, radio_rx, rx_dl_container, rx_search_container,
    widgets.HTML("<hr>"),
    # Model
    label_model, dropdown_model, out_model,
    widgets.HTML("<hr>"),
    # Antenna
    label_antenna, dropdown_antenna, out_antenna,
    widgets.HTML("<hr>"),
    btn_run,
    out_status
])

# Global variables
df_tx = None
df_rx = None
_debounce_task = None
_last_request = 0.0    # to limit the flow rate (https://operations.osmfoundation.org/policies/nominatim/)
min_delay_seconds=1.0  # respect ~1 req/s (https://operations.osmfoundation.org/policies/nominatim/)

# %% [markdown]
# ## UI callback functions

# %%
# Transmitters
def update_tx_visibility(*_):
    """
    Toggle the visibility of the transmitter input containers based on radio selection.
    Also triggers validation to keep the Run button state consistent.
    """
    out_tx.clear_output()
    if radio_tx.value == "default":
        tx_default_container.layout.display = "block"
        tx_dl_container.layout.display = "none"
        load_default_tx()
    else:
        tx_default_container.layout.display = "none"
        tx_dl_container.layout.display = "block"
    update_button_state()


def load_default_tx() -> None:
    """
    Load the default transmitters.csv file located in the current working directory.
    Updates the global df_tx and displays the preview in out_tx.

    @raises Exception: If reading the CSV fails.
    """
    global df_tx
    out_tx.clear_output()

    try:
        df_tx = pd.read_csv("transmitters.csv", sep=";")
        with out_tx:
            print("Default transmitters file loaded: transmitters.csv")
            display(df_tx.head())
    except Exception as e:
        df_tx = None
        with out_tx:
            print(f"Error loading default transmitters.csv: {e}")

    update_button_state()


def _handle_upload_tx(change: dict) -> None:
    """
    Handle the upload of transmitter files and update the global DataFrame.

    @param change: {dict} The change event triggered by the file upload widget.
    @raises Exception: If reading the CSV file fails, an error message is displayed and df_tx is set to None.
    """
    global df_tx
    out_tx.clear_output()

    if not upload_tx.value:
        with out_tx:
            print("No transmitters files")
        df_tx = None
        update_button_state()
        return

    # Content recovery
    files = upload_tx.value
    load_tx_from_csv(files)


def load_tx_from_csv(files: tuple | dict) -> None:
    """
    Loads a transmitter CSV file from an ipywidgets FileUpload widget.

    Supports both upload formats (tuple on JupyterLab, dict on Notebook), extracts
    the file content, parses it as a semicolon-separated CSV, displays a preview,
    and updates the UI state. On failure, an error message is shown.

    @param files: {tuple | dict}
        The file structure returned by the FileUpload widget.

    @raises Exception:
        If the CSV cannot be parsed (invalid format, missing data, etc.).
    """
    # Linux / JupyterLab → tuple
    if isinstance(files, tuple):
        file_info = files[0]
        filename = file_info["name"]
        content = file_info["content"]

    # Windows / Jupyter Notebook → dict
    elif isinstance(files, dict):
        filename = next(iter(files))  # first key
        file_info = files[filename]
        content = file_info["content"]

    try:
        df_tx = pd.read_csv(io.BytesIO(content), sep=";")
        df_tx_errors = validate_tx_dataframe(df_tx)
        if df_tx_errors:
            df_tx = None
            html_tx_error = widgets.HTML("")
            for error in df_tx_errors:
                html_tx_error.value += f"<b style='color:#b00020'>{error}</b><br>"
            with out_tx:
                display(html_tx_error)
        else:
            with out_tx:
                print(f"Transmitters file loaded: {filename}")
                display(df_tx.head())
    except Exception as e:
        df_tx = None
        with out_tx:
            print(f"Error reading CSV transmitters: {e}")

    update_button_state()


def validate_tx_dataframe(df: pd.DataFrame) -> list[str]:
    """
    Validate the structure and content of the transmitter CSV.

    @param df: {pd.DataFrame} The loaded transmitter dataframe.
    @return: {list[str]} A list of validation error messages. Empty if validation succeeds.
    """

    errors = []

    REQUIRED_TX_COLUMNS = [
        "transmitter name",
        "transmitter longitude",
        "transmitter latitude",
        "transmitter height",
        "azimuth",
        "downtilt",
        "frequency",
        "emitting power"
    ]

    # Check column presence
    missing = [col for col in REQUIRED_TX_COLUMNS if col not in df.columns]
    if missing:
        errors.append("Missing required columns:")
        errors += [f"  - {col}" for col in missing]
        return errors

    # Check column types and convertibility
    float_columns = [
        "transmitter longitude",
        "transmitter latitude",
        "transmitter height",
        "azimuth",
        "downtilt",
        "frequency",
        "emitting power"
    ]

    for col in float_columns:
        # Check if every value is convertible to float
        try:
            df[col].astype(float)
        except Exception:
            errors.append(f"Column '{col}' contains invalid numeric values.")

    # Check coordinate range
    if not df["transmitter longitude"].between(-180, 180).all():
        errors.append("Invalid longitude values (must be between -180 and 180).")

    if not df["transmitter latitude"].between(-90, 90).all():
        errors.append("Invalid latitude values (must be between -90 and 90).")

    # Check for NaN values
    for col in REQUIRED_TX_COLUMNS:
        if df[col].isna().any():
            errors.append(f"Column '{col}' contains missing (NaN) values.")

    return errors


# Receivers
def update_rx_visibility(*_):
    """
    Toggle the visibility of the receiver input containers based on radio selection.
    Also triggers validation to keep the Run button state consistent.
    """
    out_rx.clear_output()
    if radio_rx.value == "csv":
        rx_dl_container.layout.display = "block"
        rx_search_container.layout.display = "none"
    else:
        rx_dl_container.layout.display = "none"
        rx_search_container.layout.display = "block"
    update_button_state()


def update_button_state(*_):
    """
    Enable or disable the 'Start the calculation' button based on:
      - Transmitters dataframe loaded
      - Receivers dataframe loaded
      - Model selection (dropdown_model.value)
      - Antenna selection (dropdown_antenna.value)
    """
    tx_ready = isinstance(df_tx, pd.DataFrame)
    rx_ready = isinstance(df_rx, pd.DataFrame)
    model_ready = dropdown_model.value is not None
    antenna_ready = dropdown_antenna.value is not None

    btn_run.disabled = not (tx_ready and rx_ready and model_ready and antenna_ready)


def _handle_upload_rx(change: dict) -> None:
    """
    Handle the upload of receiver files and update the global DataFrame.

    @param change: {dict} The change event triggered by the file upload widget.
    @raises Exception: If reading the CSV file fails, an error message is displayed and df_rx is set to None.
    """
    global df_rx
    out_rx.clear_output()

    if not upload_rx.value:
        with out_rx:
            print("No receivers file")
        df_rx = None
        update_button_state()
        return

    # Content recovery
    files = upload_rx.value
    # Linux / JupyterLab → tuple
    if isinstance(files, tuple):
        file_info = files[0]
        filename = file_info["name"]
        content = file_info["content"]

    # Windows / Jupyter Notebook → dict
    elif isinstance(files, dict):
        filename = next(iter(files))  # first key
        file_info = files[filename]
        content = file_info["content"]

    try:
        df_rx = pd.read_csv(io.BytesIO(content), sep=";")
        df_rx_errors = validate_rx_dataframe(df_rx)
        if df_rx_errors:
            df_rx = None
            html_rx_error = widgets.HTML("")
            for error in df_rx_errors:
                html_rx_error.value += f"<b style='color:#b00020'>{error}</b><br>"
            with out_rx:
                display(html_rx_error)
        else:
            with out_rx:
                print(f"Receivers file loaded: {filename}")
                display(df_rx.head())
    except Exception as e:
        df_rx = None
        with out_rx:
            print(f"Error reading CSV receivers: {e}")

    update_button_state()


def validate_rx_dataframe(df: pd.DataFrame) -> list[str]:
    """
    Validate the structure and content of the receiver CSV.

    @param df: {pd.DataFrame} The loaded receiver dataframe.
    @return: {list[str]} A list of validation error messages. Empty if validation succeeds.
    """

    errors = []

    REQUIRED_RX_COLUMNS = [
        "receiver name",
        "receiver longitude",
        "receiver latitude",
        "receiver height"
    ]

    # Check column presence
    missing = [col for col in REQUIRED_RX_COLUMNS if col not in df.columns]
    if missing:
        errors.append("Missing required columns:")
        errors += [f"  - {col}" for col in missing]
        return errors

    # Check column types and convertibility
    float_columns = [
        "receiver longitude",
        "receiver latitude",
        "receiver height"
    ]

    for col in float_columns:
        # Check if every value is convertible to float
        try:
            df[col].astype(float)
        except Exception:
            errors.append(f"Column '{col}' contains invalid numeric values.")

    # Check coordinate range
    if not df["receiver longitude"].between(-180, 180).all():
        errors.append("Invalid longitude values (must be between -180 and 180).")

    if not df["receiver latitude"].between(-90, 90).all():
        errors.append("Invalid latitude values (must be between -90 and 90).")

    # Check for NaN values
    for col in REQUIRED_RX_COLUMNS:
        if df[col].isna().any():
            errors.append(f"Column '{col}' contains missing (NaN) values.")

    return errors


def _on_text_change_rx(change: dict) -> None:      
    """
    Triggered on every keystroke and uses debouncing to delay processing.

    @param change: {dict} The change event emitted by the text input widget, 
        containing the updated value under the "new" key.
    @raises Exception: If the debounced fetch operation fails, an exception may be 
        raised during the execution of the scheduled callback.
    """
    global _debounce_task, df_rx
    query = change["new"]

    # Reset receiver dataframe
    df_rx = None
    out_rx.clear_output()
    update_button_state()
    
    # Cancel previous scheduled call
    if _debounce_task and not _debounce_task.done():
        _debounce_task.cancel()

    # Schedule a new debounced call
    _debounce_task = asyncio.create_task(_debounce_wrapper(query))


async def _debounce_wrapper(query: str) -> None:
    """
    Waits for a short delay before triggering the debounced fetch operation.

    @param query: {str} The text entered by the user that should be processed 
        after the debounce delay has elapsed.
    @raises asyncio.CancelledError: Raised when the pending debounce task is 
        cancelled due to new user input, which is expected behavior in a debounce 
        mechanism.
    """
    try:
        await asyncio.sleep(0.5)
        await _debounced_fetch(query)
    except asyncio.CancelledError:
        # Debounce cancelled: normal behavior
        pass


async def _debounced_fetch(query: str) -> None:
    """
    Triggered after a pause in typing and performs the asynchronous fetching
    of address suggestions, including rate limiting and result processing.

    @param query: {str} The text entered by the user after debouncing, 
        representing the search query to be processed.
    @raises Exception: If the search request or the processing of returned data 
        fails, an exception may be raised and an error message is displayed in 
        the status widget.
    """
    global _last_request
    query = query.strip()
    if len(query) < 3:
        _set_suggestions([])
        status.value = "<i>Keep typing (at least 3 characters)…</i>"
        return

    # Rate limit (>= 1s between requests)
    now = time.time()
    wait = (_last_request + min_delay_seconds) - now
    if wait > 0:
        time.sleep(wait)

    try:
        status.value = "<i>Research in progress…</i>"
        data = _nominatim_search(query)
        _last_request = time.time()

        # Keep the useful fields (lat/lon, display_name, etc.)
        cleaned = []
        for item in data:
            cleaned.append({
                "display_name": item.get("display_name"),
                "lat": float(item["lat"]),
                "lon": float(item["lon"]),
                "type": item.get("type"),
                "class": item.get("class"),
                "address": item.get("address", {})
            })

        _set_suggestions(cleaned)
        status.value = f"<i>{len(cleaned)} suggestion(s) found. Select one.</i>"

    except Exception as e:
        _set_suggestions([])
        status.value = f"<b style='color:#b00020'>Erreur:</b> {e}"


def _set_suggestions(results: dict) -> None:
    """
    Updates the Select widget with formatted suggestion entries.

    @param results: {dict} A list of suggestion items, each containing fields such 
        as display_name, coordinates, and additional metadata. When empty, the 
        Select widget is cleared and hidden.
    @raises Exception: No explicit exception is raised by this function, but any 
        issue related to widget assignment or unexpected result structure may 
        result in runtime errors during UI updates.
    """
    if not results:
        suggestions_rx.options = []
        suggestions_rx.value = None
        suggestions_rx.layout.display = "none"
        return

    options = []
    suggestions_rx.layout.display = ""
    for res in results:
        label = res["display_name"]
        options.append((label, res))
    suggestions_rx.options = options
    suggestions_rx.value = None


def _nominatim_search(query: str) -> None:
    """
    Performs a Nominatim Search request and returns the list of matching results.

    @param query: {str} The text query to send to the Nominatim API in order to 
        retrieve location suggestions and associated metadata.
    @raises Exception: If the HTTP request fails or the remote service returns an 
        error status, an exception is raised through `raise_for_status()` before 
        returning the parsed JSON response.
    """
    params = {
        "q": query,
        "format": "jsonv2",
        "limit": 5,
        "addressdetails": 1
    }

    headers = {"User-Agent": "BloonetWebServicesNotebook/1.0"}

    r = requests.get(NOMINATIM_URL, params=params, headers=headers, timeout=15)
    r.raise_for_status()
    return r.json()


def _on_select_rx(change: dict) -> None:
    """
    Handles the event triggered when the user selects a suggestion and updates
    the receiver DataFrame and displayed coordinates accordingly.

    @param change: {dict} The change event emitted by the Select widget, containing 
        the newly selected suggestion under the "new" key.
    @raises Exception: Although no explicit exception is raised by this function, 
        errors may occur if the selected item has an unexpected structure or if the 
        DataFrame update or UI rendering encounters issues.
    """
    global df_rx
    val = change["new"]
    if not val:
        return

    lat, lon = val["lat"], val["lon"]
    name = normalize_receiver_name(val["display_name"])

    df_rx = pd.DataFrame([{
        "receiver name": name,
        "receiver longitude": lon,
        "receiver latitude": lat,
        "receiver height": RECEPTION_HEIGHT
    }])

    out_rx.clear_output()
    with out_rx:
        print("✅ Selection:")
        print(name)
        print("")
        print("Coordinates:")
        print(f"Latitude  : {lat}")
        print(f"Longitude : {lon}")
    
    update_button_state()


def normalize_receiver_name(raw: str) -> str:
    """
    Normalizes an address string into a safe, <=100 character receiver name

    @param raw: {str} The original address string from which a compact and 
        standardized receiver name should be generated.
    @raises Exception: This function does not explicitly raise exceptions, but 
        malformed input or unexpected string formats may lead to runtime errors 
        during text processing operations.
    """
    # Keep only the first 3 elements (name + address + city)
    parts = raw.split(",")
    essential = " ".join(p.strip() for p in parts[:3])
    
    # Lowercase letters
    text = essential.lower()

    # Replace any non-alphanumeric character with '_'
    text = re.sub(r"[^a-z0-9]+", "_", text)

    # Clean up underscores at the beginning/end
    text = text.strip("_")

    # If too long, truncate neatly
    if len(text) > 100:
        cut = text[:100]
        # Avoid cutting in the middle of a word
        if "_" in cut:
            cut = cut[:cut.rfind("_")]
        text = cut

    return text

# Load default tx by default
load_default_tx()

# Connect callbacks to widgets
radio_tx.observe(update_tx_visibility, names="value")
upload_tx.observe(_handle_upload_tx, names="value")
radio_rx.observe(update_rx_visibility, names="value")
upload_rx.observe(_handle_upload_rx, names="value")
search_rx.observe(_on_text_change_rx, names="value")
suggestions_rx.observe(_on_select_rx, names="value")

# %% [markdown]
# ## API calls functions

# %%
def create_session() -> dict:
    """
    Create a new session on the BWS server and return its details.

    @return: {dict} A dictionary containing the session information returned by the BWS API.
    @raises RuntimeError: If the BWS API does not return a 201 status code, indicating session creation failed.
    """

    # Session information
    session = {
        "uuid": str(SESSION_UUID),
        "name": "session_notebook_mp2mp",
        "description": "Session sample MP to MP from Jupyter Notebook"
    }

    # Post session to BWS server
    response = call_request(
        method="POST",
        url=f"{BWS_API_URL}/sessions",
        authentication_data=AUTHENTICATION,
        json_content=session
    )
    result = response.json()

    if response.status_code != 201:
        with out_status:
            print(f"Error call create session: {result['message']}")
    
    return result


def create_simulation(network_list: pd.DataFrame, antenna_uuid: str, model_uuid: str) -> list:
    """
    Build and submit a multi-point to multi-point simulation request to the BWS server.

    @param network_list: {pd.DataFrame} Structured table of links (transmitters/receivers) and radio parameters.
    @param antenna_uuid: {str} UUID of the antenna to associate with each base station.
    @param model_uuid: {str} UUID of the propagation model to apply.

    @return: {list} The BWS API response body (parsed JSON) describing the created simulation.
    @raises RuntimeError: If the BWS API does not return HTTP 201 (simulation creation failed).
    """
    # Create simulation object
    propagation_list = []
    for _, network in network_list.iterrows():

        new_base_station = {
            "x": float(network["transmitter longitude"]),
            "y": float(network["transmitter latitude"]),
            "z": float(network["transmitter height"]),
            "epsgCode": 4326,
            "zmeaning": "ZMEANING_GROUND",
            "azimuth": float(network["azimuth"]),
            "downtilt": float(network["downtilt"]),
            "carrierFrequency": float(network["frequency"]),
            "description": "",
            "sessionUuid": str(SESSION_UUID),
            "name": network["transmitter name"],
            "networkId": network["transmitter id"],
            "transmitPower": float(network["emitting power"]),
            "antennaUuid": antenna_uuid
        }

        new_user_equipment = {
            "sessionUuid": str(SESSION_UUID),
            "description": "",
            "zmeaning": "ZMEANING_GROUND",
            "type": "POINT",
            "name": network["receiver name"],
            "heights": [network["receiver height"]],
            "coordinates": {
                "x": network["receiver longitude"],
                "y": network["receiver latitude"],
                "epsgCode": 4326
            }
        }

        already_exist = False
        for propagation in propagation_list:
            base_station = propagation["baseStation"]
            if is_same_base_station(base_station, new_base_station):
                if new_user_equipment["type"] == "POINT":
                    propagation["userEquipments"].append(new_user_equipment)
                    already_exist = True
                    break

        if not already_exist:
            new_propagation = {
                "baseStation": new_base_station,
                "userEquipments": [new_user_equipment],
                "propagationModelUuid": model_uuid
            }
            propagation_list.append(new_propagation)
        
    simulation_request = {
        "uuid": str(SIMULATION_UUID),
        "name": "session_sample_mp2mp_notebook_simulation",
        "calculationSessionUuid": str(SESSION_UUID),
        "propagationRequest": {
            "propagationScenarios": propagation_list,
            "resultTypes": ["RECEIVED_POWER"],
            "zmeaning": "ZMEANING_GROUND"
        }
    }

    multipart_form_data = [("json", (None, json.dumps(simulation_request), "application/json")), *[]]

    # Post simulation to BWS server
    response = call_request(
        method="POST",
        url=f"{BWS_API_URL}/simulations",
        authentication_data=AUTHENTICATION,
        files=multipart_form_data
    )
    simulation = response.json()

    if response.status_code != 201:
        with out_status:
            print(f"Error call create simulations: {simulation['message']}")
    
    return simulation


def wait_for_simulation() -> None:
    """
    Monitor the status of the current BWS simulation until it completes or fails.

    @summary:
        Initializes a Jupyter FloatProgress widget and repeatedly polls the BWS
        simulation status endpoint every 5 seconds. The progress bar and status
        message are updated in place inside the `out_status` widget. The loop ends
        when the simulation reaches state "DONE" or "ERROR". On completion, the
        progress bar is marked as successful; on failure, it is displayed in
        error style and the function stops immediately.
    """
    
    with out_status:
        progress = widgets.FloatProgress(
            value=0.0,
            min=0.0,
            max=100.0,
            step=0.1,
            description='Progress:'
        )
        status = widgets.HTML("<b>Waiting…</b>")
        box = widgets.VBox([progress, status])
        display(box)

    last_prg = None
    while True:
        time.sleep(5)
        response = call_request(
            method="GET",
            url=f"{BWS_API_URL}/simulations/{str(SIMULATION_UUID)}/status",
            authentication_data=AUTHENTICATION
        ).json()

        prg = float(response.get("progress", 0.0) or 0.0)
        state = (response.get("state") or "").upper()

        if last_prg != prg:
            progress.value = prg
            last_prg = prg
            status.value = f"<b>State:</b> {state} &nbsp; | &nbsp; <b>Progress:</b> {prg:.1f}%"

        if state == "DONE":
            progress.value = 100.0
            progress.bar_style = 'success'
            status.value = f"<b>Simulation {SIMULATION_UUID}</b> finished with state <b>DONE</b>."
            break

        if state == "ERROR":
            progress.bar_style = 'danger'
            status.value = f"<b>Simulation {SIMULATION_UUID}</b> finished with <b>ERROR</b>"
            break


def download_simulation_results() -> list:
    """
    Download all generated result files for the current simulation and return their local paths.

    @return: {list} A list of dictionaries with normalized file names and absolute file paths.
    """

    simulation_results = []
    # Create and/or clean the tmp results folder
    results_path = Path("/tmp/results")
    if results_path.exists():
        shutil.rmtree(results_path, ignore_errors=True)
    results_path.mkdir(parents=True, exist_ok=True)
    # Retrieve the simulation results
    res = call_request(
        method="GET",
        url=f"{BWS_API_URL}/simulations/{str(SIMULATION_UUID)}/results",
        authentication_data=AUTHENTICATION
    )

    results = res.json()

    with out_status:
        if res.status_code in (404, 400):
            print(f"Error simulation {SIMULATION_UUID}: {results['message']}")
            return
        for result in results:
            # Download the tif files
            current_tiff = call_request(
                method="GET",
                url=f"{BWS_DL_URL}/results/{str(result['uuid'])}/download",
                authentication_data=AUTHENTICATION
            )
            
            if current_tiff.status_code != 200:
                print(f"Error downloading {result['fileName']}")
            
            # Save this tif files in tmp folder
            file_path = f"/tmp/results/{result['fileName']}"
            with open(file_path, "wb") as result_file:
                result_file.write(current_tiff.content)
            
            filename = result["fileName"].rsplit(".", 1)[0]
            
            simulation_results.append({
                "name": filename.replace("-", "_").replace(".", "_"),
                "path": file_path
            })
    
    return simulation_results


def generate_mp2mp_matrix(results_file: list, metric_name="received_power") -> pd.DataFrame:
    """
    Build a receiver x transmitter matrix DataFrame from MP-to-MP JSON result files.

    @summary:
        Iterates over a list of result file descriptors (each containing a local file path),
        loads the JSON payload, extracts long-form rows using `extract_rows_from_json()`,
        and pivots them into a wide-form matrix:
            - index: receiver names
            - columns: "<transmitter>_<metric_name>"
            - values: metric values (e.g., received power)
        Returns the resulting `pandas.DataFrame`. If no rows are found, returns an empty DataFrame.

    @param results_file: {list} List of result file descriptors. Each item must include a `"path"` key
        pointing to a local JSON file produced by the MP-to-MP process.
    @param metric_name: {str} Metric to extract and pivot (default: "received_power").

    @return: {pd.DataFrame} Wide-form matrix with receivers in rows and transmitters as metric-specific columns.
    @raises FileNotFoundError: If any referenced result file path does not exist.
    @raises RuntimeError: If a result file cannot be read or parsed as JSON.
    """

    all_rows = []
    for result_file in results_file:
        result_file_path = Path(result_file["path"])
        if not result_file_path.exists():
            error = f"File {result_file_path} not found"
            with out_status:
                print(error)
            raise FileNotFoundError(error)
        try:
            with open(result_file_path, "r", encoding="utf-8") as file:
                data = json.load(file)
            all_rows.extend(extract_rows_from_json(data, metric_name=metric_name))
        except Exception as e:
            error = f"Cannot read {result_file_path} file: {e}"
            with out_status:
                print(error)
            raise RuntimeError(error)
    df_long = pd.DataFrame(all_rows)
    if df_long.empty:
        return pd.DataFrame()
    
    df = df_long.pivot_table(
        index="receiver",
        columns="transmitter",
        values=metric_name,
        aggfunc="first"
    )
    df.columns = [f"{c}_{metric_name}" for c in df.columns]
    df = df.sort_index()
    return df


def generate_kpi(df_matrix: pd.DataFrame, metric_name="received_power") -> pd.DataFrame:
    """
    Generate KPI metrics from a matrix of received powers.

    @param df_matrix: {pd.DataFrame} Input matrix containing receiver name + one column per TX
                      in the form "<tx_name>_received_power".
    @param metric_name: {str} Transmitter suffix in matrix columns
    @return: {pd.DataFrame} KPI table with Rx name, best signal, best server, throughput.
    """
    # Load mapping (power threshold → throughput)
    mapping = pd.read_csv("mapping_power_throughput.csv", sep=";")
    try:
        df_kpi = df_matrix.apply(
            lambda row: compute_kpi_row(row, mapping),
            axis=1
        )
    except Exception as e:
        with out_status:
            print("ERROR:", e)

    return df_kpi


def compute_kpi_row(row: pd.Series, mapping: pd.DataFrame) -> pd.Series:  
    """
    Compute KPI for a single receiver row.
    """
    # Max power (best signal)
    best_signal = row.max(skipna=True)
    # Best server (column name → tx name)
    best_site = row.idxmax(skipna=True).replace("_received_power", "")
    # Map best signal to nearest throughput
    eligible = mapping[mapping["power"] <= best_signal]

    if not eligible.empty:
        throughput = eligible.iloc[-1]["throughput"]
    else:
        throughput = np.nan  # signal too low

    return pd.Series({
        "Rx name": row.name,
        "Best signal (dBm)": best_signal,
        "Best server": best_site,
        "Throughput (MBps)": throughput
    })


def check_missing_receivers(df_rx: pd.DataFrame, df_network: pd.DataFrame) -> None:
    """
    Check whether each receiver in df_rx appears at least once in df_network.
    If a receiver has no associated transmitter in the filtered network,
    a warning is issued.

    Parameters
    ----------
    @param df_rx: {pd.DataFrame} The dataframe containing all receivers.
    @param df_network: {pd.DataFrame} The dataframe generated by build_filtered_network(),
                                      containing (transmitter, receiver) pairs.
    """
    # Extract the set of receivers actually present in the network result
    rx_in_network = set(df_network["receiver name"].unique())

    # Extract the set of expected receivers
    rx_expected = set(df_rx["receiver name"].unique())

    # Identify missing receivers
    missing = rx_expected - rx_in_network

    # Display warnings in the widget
    with out_status:
        for rx_name in missing:
            print(f"⚠️ No transmitter found within {RECEIVER_BUFFER_RADIUS_M/1000:.1f} km of receiver '{rx_name}'")


def geodesic_buffer(lon: float, lat: float, n=180) -> Polygon:
    """
    Generate a geodesic buffer (WGS84) around a geographic point defined by (lon, lat).

    This function computes a polygon representing a circular buffer on the Earth's
    ellipsoid (WGS84), using forward geodesic calculations from the given center
    point. The buffer radius is defined by RECEIVER_BUFFER_RADIUS_M.

    @param lon: {float} Longitude of the buffer center point, in decimal degrees.
    @param lat: {float} Latitude of the buffer center point, in decimal degrees.
    @param n: {int} Number of azimuth sampling steps used to approximate the geodesic circle
            (more points → smoother polygon). Default: 180.

    @return: {shapely.geometry.Polygon} A geodesic buffer polygon approximating a circle
            of radius RECEIVER_BUFFER_RADIUS_M around the input point.

    @raises ValueError: If the input coordinates are invalid or cannot be projected.
    """
    lons, lats = [], []
    geod = Geod(ellps="WGS84")
    for az in range(0, 360, 360 // n):
        lon2, lat2, _ = geod.fwd(lon, lat, az, RECEIVER_BUFFER_RADIUS_M)
        lons.append(lon2)
        lats.append(lat2)
    return Polygon(zip(lons, lats))


def build_filtered_network(df_tx, df_rx) -> pd.DataFrame:
    """
    Build a filtered transmitter-receiver network by keeping only (tx, rx) pairs
    where the transmitter lies within the geodesic buffer around each receiver.

    This function iterates over all receivers, computes a WGS84 geodesic buffer
    (via `geodesic_buffer`) centered at each receiver position, and retains any
    transmitter whose coordinates fall inside that buffer. The output is a flat,
    denormalized table of (tx, rx) pairs with the key radio fields preserved.

    @param df_tx: {pd.DataFrame} Table of transmitters
    @param df_rx: {pd.DataFrame} Table of receivers
    @return: {pd.DataFrame} A denormalized table where each row represents a (tx, rx)
            pair that satisfies the spatial constraint (tx ∈ geodesic buffer around rx).

    @raises KeyError: If required columns are missing from `df_tx` or `df_rx`.
    @raises ValueError: If coordinate values are invalid (e.g., out of WGS84 bounds) or if
                        the geodesic buffer cannot be constructed.
    """
    rows = []

    for _, rx in df_rx.iterrows():
        # Build the receiver buffer
        buf = geodesic_buffer(rx["receiver longitude"], rx["receiver latitude"])

        for _, tx in df_tx.iterrows():
            pt = Point(tx["transmitter longitude"], tx["transmitter latitude"])

            if buf.contains(pt):
                rows.append({
                    "transmitter id": tx["transmitter id"],
                    "transmitter name": tx.get("transmitter name", None),
                    "transmitter longitude": tx["transmitter longitude"],
                    "transmitter latitude": tx["transmitter latitude"],
                    "transmitter height": tx["transmitter height"],
                    "azimuth": tx["azimuth"],
                    "downtilt": tx["downtilt"],
                    "frequency": tx["frequency"],
                    "emitting power": tx["emitting power"],

                    "receiver name": rx["receiver name"],
                    "receiver longitude": rx["receiver longitude"],
                    "receiver latitude": rx["receiver latitude"],
                    "receiver height": rx["receiver height"]
                })

    return pd.DataFrame(rows)

# %% [markdown]
# ## Calculation actions

# %%
def on_run_clicked(b: widgets.Button) -> None:
    """
    Executes the simulation workflow when the button is clicked in the UI.

    This function:
      1. Validates that both datasets `df_tx` (transmitters) and `df_rx` (receivers) are loaded,
         and that a propagation model (`dropdown_model`) and an antenna (`dropdown_antenna`) are selected.
      2. Builds the Cartesian product TXxRX to create the network and assigns a unique,
         incremental transmitter ID ("transmitter id").
      3. Creates a session, initializes and runs the simulation, waits for completion,
         then downloads the results.
      4. Generates a multi-point-to-multi-point (mp2mp) matrix from the results.
      5. Displays the matrix and saves it as a CSV file.
      6. Logs progress and messages in the output widget.

    @param b: Event object passed by `ipywidgets.Button.on_click` (not used directly,
        but required by the callback signature).
    """
    global SESSION_UUID, SIMULATION_UUID
    out_status.clear_output()

    if df_tx is None or df_rx is None:
        with out_status:
            print("Transmitters and receivers must be loaded correctly")
        return
    
    if dropdown_model.value is None:
        with out_status:
            print("A model must be selected")
        return
    
    if dropdown_antenna.value is None:
        with out_status:
            print("An antenna must be selected")
        return
    
    df_tx["transmitter id"] = range(1, len(df_tx) + 1)
    df_network = build_filtered_network(df_tx, df_rx)

    with out_status:
        if df_network.empty:
            print(f"No transmitter is within {RECEIVER_BUFFER_RADIUS_M/1000:.1f} km of any receiver. Aborting.")
            return
        print("Starting calculations")
    check_missing_receivers(df_rx, df_network)
    SESSION_UUID = uuid.uuid4()
    create_session()
    SIMULATION_UUID = uuid.uuid4()
    create_simulation(df_network, dropdown_antenna.value, dropdown_model.value)
    wait_for_simulation()
    results = download_simulation_results()
    df_matrix = generate_mp2mp_matrix(results)
    df_kpi = generate_kpi(df_matrix)
    with out_status:
        print("Results matrix:")
        display(df_matrix)
        matrix_path = "matrix_received_power.csv"
        df_matrix.reset_index().to_csv(matrix_path, sep=";", index=False)
        print(f"Save results in csv format under {matrix_path}")
        print()
        print("Results KPI:")
        display(df_kpi.reset_index(drop=True))
        kpi_path = "kpi.csv"
        df_kpi.to_csv(kpi_path, sep=";", index=False)
        print(f"Save results in csv format under {kpi_path}")

btn_run.on_click(on_run_clicked)
display

# %% [markdown]
# ## UI Display

# %%
display(ui)
