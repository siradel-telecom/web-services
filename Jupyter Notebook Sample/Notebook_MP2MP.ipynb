# %% [markdown]
# # Bloonet Jupyter Notebook

# %% [markdown]
# ## Required imports

# %%
import requests
import uuid
import json
import time
import shutil
import pandas as pd
import numpy as np
import io
import asyncio
import re
import ipywidgets as widgets
from IPython.display import display
from typing import Union, Optional, Any
from pathlib import Path
from shapely.geometry import Polygon, Point
from pyproj import Geod

# %% [markdown]
# ## Required constants
# Update your authentication information before running a calculation.

# %%
SESSION_UUID = None
SIMULATION_UUID = None
BWS_API_URL = "https://api.bloonetws.siradel.com"
BWS_DL_URL = "https://dl.bloonetws.siradel.com"
NOMINATIM_URL = "https://nominatim.openstreetmap.org/search"
RECEPTION_HEIGHT = 2
RESOLUTION = 10
RECEIVER_BUFFER_RADIUS_M = 160000
ACCESS_TOKEN = None
REFRESH_TOKEN = None
AUTHENTICATION = {
    "url": "https://keycloak.bloonetws.siradel.com/realms/volcanoweb/protocol/openid-connect/token",
    "clientId": "volcano-web-cli",
    "username": "USERNAME",
    "password": "PASSWORD"
}

# %% [markdown]
# ## Required functions

# %%
def call_request(method: str, url: str, authentication_data: dict,
                 files: list = None, json_content: Union[dict, list] = None,
                 params: dict = None, retry: int = 0, timeout=None) -> requests.Response:
    """
    Call requests with args for use authenticate

    @param method: {str} method request
    @param url: {str} url request
    @param authentication_data: {dict} authentication data
    @param files: {list} files request
    @param json_content: {dict} json request
    @param params: {dict} params request
    @param retry: {int} number of retry
    @param timeout: {Any} timeout request

    @return: {request.Response} response of request
    """

    headers = None

    if authentication_data is None:
        print("Authentication data needed")
    token = get_access_token(authentication_data)
    headers = {"Authorization": f"Bearer {token}"}

    res = None
    if method.upper() == "POST":
        res = requests.post(url=url, files=files, json=json_content, params=params,
                            timeout=timeout, headers=headers)
    elif method.upper() == "PUT":
        res = requests.put(url=url, files=files, json=json_content, params=params,
                           timeout=timeout, headers=headers)
    elif method.upper() == "GET":
        res = requests.get(url=url, files=files, json=json_content, params=params,
                           timeout=timeout, headers=headers)
    elif method.upper() == "DELETE":
        res = requests.delete(url=url, files=files, json=json_content, params=params,
                              timeout=timeout, headers=headers)
    else:
        raise ValueError("Method name %S not implemented", method.upper())

    # If access_token expires, refresh the token one time and recall requests
    if res.status_code == 403 and retry == 0:
        refresh_token(authentication_data)
        res = call_request(
            method,
            url,
            authentication_data,
            files,
            json_content,
            params,
            1,
            timeout
        )

    return res


def get_access_token(authentication_data: dict) -> str:
    """
    Retrieve an access token

    @param authentication_data: {dict} authentication data

    @return: {str} access token provided
    """

    global ACCESS_TOKEN, REFRESH_TOKEN
    if ACCESS_TOKEN is not None:
        return ACCESS_TOKEN
    payload = {
        "grant_type": "password",
        "client_id": authentication_data["clientId"],
        "username": authentication_data["username"],
        "password": authentication_data["password"]
    }

    response = requests.post(
        authentication_data["url"],
        data=payload
    )

    json_response = response.json()

    if response.status_code == 200:
        ACCESS_TOKEN = json_response["access_token"]
        REFRESH_TOKEN = json_response["refresh_token"]
    else:
        raise RuntimeError("Error call get access token: %s", json_response["error_description"])
    return ACCESS_TOKEN


def refresh_token(authentication_data: dict) -> None:
    """
    Refresh the access token

    @param authentication_data: {dict} authentication data
    """

    global ACCESS_TOKEN, REFRESH_TOKEN
    if REFRESH_TOKEN is None:
        raise RuntimeError("Error call refresh token : refresh token is empty")

    payload = {
        "grant_type": "refresh_token",
        "client_id": authentication_data["clientId"],
        "refresh_token": REFRESH_TOKEN
    }

    response = requests.post(
        authentication_data["url"],
        data=payload
    )

    json_response = response.json()

    if response.status_code == 200:
        ACCESS_TOKEN = json_response["access_token"]
        REFRESH_TOKEN = json_response["refresh_token"]
    else:
        raise RuntimeError("Error call get refresh token: %s", json_response["error_description"])


def is_same_base_station(base_station_1: dict, base_station_2: dict) -> bool:
    """
    Check if the two base stations in parameter are the same

    @param base_station_1: {dict} first base station to compare
    @param base_station_2: {dict} second base station to compare

    @return: {bool} True if equals, False else
    """
    return (
            base_station_1["networkId"] == base_station_2["networkId"] and
            base_station_1["name"] == base_station_2["name"] and
            base_station_1["x"] == base_station_2["x"] and
            base_station_1["y"] == base_station_2["y"] and
            base_station_1["z"] == base_station_2["z"] and
            base_station_1["azimuth"] == base_station_2["azimuth"] and
            base_station_1["downtilt"] == base_station_2["downtilt"] and
            base_station_1["carrierFrequency"] == base_station_2["carrierFrequency"] and
            base_station_1["transmitPower"] == base_station_2["transmitPower"]
    )


def extract_rows_from_json(obj: dict, metric_name: str) -> list: 
    """
    Extract transmitter-receiver metric rows from a JSON object.

    @param obj: {dict} JSON-like object representing simulation results, expected to contain
        a "transmitters" key with nested receiver data.
    @param metric_name: {str} Name of the metric to extract from receiver qualifications
        (e.g., "received_power").

    @return: {list} A list of dictionaries, each with keys:
        - "receiver": Receiver name
        - "transmitter": Transmitter name
        - <metric_name>: Extracted metric value (or None if not found)
    """
    rows = []
    for tx in obj.get("transmitters", []):
        tx_name = tx.get("name")
        for rx in tx.get("receivers", []):
            rx_name = rx.get("name")
            value = None
            for q in rx.get("qualifications", []):
                if q.get("name") == metric_name:
                    value = q.get("value")
                    break
            rows.append({"receiver": rx_name, "transmitter": tx_name, metric_name: value})
    return rows


def get_public_models() -> list:
    """
    Retrieve the public models

    @return: {list} list of public models
    """
    response = call_request(
        method="GET",
        url=f"{BWS_API_URL}/propagationmodels",
        authentication_data=AUTHENTICATION
    )
    public_models_list = response.json()

    if response.status_code != 200:
        raise RuntimeError("Error call get public models: %s", public_models_list["error_description"])

    PUBLIC_MODELS_NAME = ["fixed wireless access", "mobility"]
    public_models = [model for model in public_models_list if model["name"].lower() in PUBLIC_MODELS_NAME and model["type"] is None]
    return public_models


def get_public_antennas() -> list:
    """
    Retrieve the public antennas

    @return: {list} list of public antennas
    """
    response = call_request(
        method="GET",
        url=f"{BWS_API_URL}/antennas",
        authentication_data=AUTHENTICATION
    )
    public_antennas_list = response.json()

    if response.status_code != 200:
        raise RuntimeError("Error call get public antennas: %s", public_antennas_list["error_description"])

    PUBLIC_ANTENNAS_NAME = [
        "tarana-bn-3ghz-compact-r0",
        "tarana-bn-5ghz-r1",
        "tarana-bn-6ghz-r2",
        "tarana-bn-6ghz-x2-r2"
    ]
    public_antennas = [antenna for antenna in public_antennas_list if antenna["name"].lower() in PUBLIC_ANTENNAS_NAME]
    return public_antennas

# %% [markdown]
# ## UI Class

# %%
class CoverageUI:
    """
    Interactive UI for configuring and running MP2MP radio coverage simulations
    in a Jupyter environment.

    This class provides:
    - CSV upload and validation for transmitters and receivers
    - Optional receiver lookup through Nominatim (with async debouncing)
    - Selection of propagation models and antenna patterns
    - Spatial filtering of TX/RX links using geodesic buffers (WGS84)
    - Automated creation of BWS sessions and simulations
    - Live simulation monitoring with a progress bar
    - Download of produced results (GeoTIFF/JSON)
    - Generation of MP2MP matrices and KPI tables

    All interactions, feedback messages, and errors are displayed inside
    ipywidgets output panes.
    """

    def __init__(self) -> None:
        """
        Initialize CoverageUI state and build/connect the widgets.
        """
        self.df_tx = None
        self.df_rx = None
        self._debounce_task = None
        self._last_request = 0.0
        self.min_delay_seconds = 1.0  # respect Nominatim policy

        self._build_widgets()
        self._connect_callbacks()

        # Load default transmitters on startup
        self.load_default_tx()


    # ----------------------------------------------------------
    #                WIDGET CONSTRUCTION
    # ----------------------------------------------------------
    def _build_widgets(self) -> None:
        """
        Initialize and arrange all UI components.
        """
        # ---------- Outputs ----------
        self.out_default_tx = widgets.Output()
        self.out_dl_tx = widgets.Output()
        self.out_dl_rx = widgets.Output()
        self.out_search_rx = widgets.Output()
        self.out_status = widgets.Output()

        # ---------- Transmitters ----------
        self.radio_tx = widgets.RadioButtons(
            options=[
                ("Use default transmitters", "default"),
                ("Upload CSV file for the transmitters", "csv")
            ],
            value="default"
        )

        self.upload_tx = widgets.FileUpload(accept=".csv", multiple=False)

        self.tx_default_container = widgets.VBox([self.out_default_tx])
        self.tx_dl_container = widgets.VBox([
            widgets.Label("Select the CSV file for the transmitters:"),
            self.upload_tx,
            self.out_dl_tx
        ])
        self.tx_dl_container.layout.display = "none"

        # ---------- Receivers ----------
        self.radio_rx = widgets.RadioButtons(
            options=[
                ("Upload CSV file for the receivers", "csv"),
                ("Enter a receiver address", "address")
            ],
            value="csv"
        )

        self.upload_rx = widgets.FileUpload(accept=".csv", multiple=False)

        self.search_rx = widgets.Text(
            placeholder="Enter a receiver address",
            description="Address:",
            layout=widgets.Layout(width="50%")
        )

        self.suggestions_rx = widgets.Select(
            options=[],
            rows=6,
            layout=widgets.Layout(width="70%", display="none")
        )
        self.status = widgets.HTML("<i>Start typing to see suggestions…</i>")

        self.rx_dl_container = widgets.VBox([
            widgets.Label("Select the CSV file for the receivers:"),
            self.upload_rx,
            self.out_dl_rx
        ])

        self.rx_search_container = widgets.VBox([
            widgets.Label("Enter a receiver address:"),
            self.search_rx,
            self.suggestions_rx,
            self.status,
            self.out_search_rx
        ])
        self.rx_search_container.layout.display = "none"

        # ---------- Model / Antenna ----------
        self.dropdown_model = widgets.Dropdown(
            options=[(m["name"], m["uuid"]) for m in get_public_models()]
        )
        self.dropdown_antenna = widgets.Dropdown(
            options=[(a["name"], a["uuid"]) for a in get_public_antennas()]
        )

        # ---------- Run button ----------
        self.btn_run = widgets.Button(
            description="Start the calculation",
            button_style="primary",
            disabled=True
        )

        # ---------- Final UI ----------
        self.root = widgets.VBox([
            widgets.HTML("<h3><b>Transmitters</b></h3>"),
            self.radio_tx,
            self.tx_default_container,
            self.tx_dl_container,
            widgets.HTML("<hr>"),

            widgets.HTML("<h3><b>Receivers</b></h3>"),
            self.radio_rx,
            self.rx_dl_container,
            self.rx_search_container,
            widgets.HTML("<hr>"),

            widgets.HTML("<b>Select propagation model:</b>"),
            self.dropdown_model,
            widgets.HTML("<hr>"),

            widgets.HTML("<b>Select antenna pattern:</b>"),
            self.dropdown_antenna,
            widgets.HTML("<hr>"),

            self.btn_run,
            self.out_status
        ])


    # ----------------------------------------------------------
    #               CONNECT CALLBACKS
    # ----------------------------------------------------------
    def _connect_callbacks(self) -> None:
        """
        Bind widget events to their related callback methods.
        """
        self.radio_tx.observe(self.update_tx_visibility, "value")
        self.upload_tx.observe(self._handle_upload_tx, "value")

        self.radio_rx.observe(self.update_rx_visibility, "value")
        self.upload_rx.observe(self._handle_upload_rx, "value")

        self.search_rx.observe(self._on_text_change_rx, "value")
        self.suggestions_rx.observe(self._on_select_rx, "value")

        self.btn_run.on_click(self.on_run_clicked)


    # ----------------------------------------------------------
    #               TRANSMITTERS MANAGEMENT
    # ----------------------------------------------------------
    def update_tx_visibility(self, *_) -> None:
        """
        Toggle transmitter input containers depending on radio selection.
        """
        if self.radio_tx.value == "default":
            self.tx_default_container.layout.display = "block"
            self.tx_dl_container.layout.display = "none"
            self.load_default_tx()
        else:
            self.tx_default_container.layout.display = "none"
            self.tx_dl_container.layout.display = "block"
        self.update_button_state()


    def load_default_tx(self) -> None:
        """
        Load the default `transmitters.csv` from the working directory.
        """
        self.out_default_tx.clear_output()
        try:
            df = pd.read_csv("transmitters.csv", sep=";")
            self.df_tx = df
            with self.out_default_tx:
                print("Default transmitters file loaded.")
                display(df.head())
        except Exception as e:
            self.df_tx = None
            with self.out_default_tx:
                print(f"Error loading default transmitters.csv: {e}")
        self.update_button_state()


    def _handle_upload_tx(self, change: dict) -> None:
        """
        Handle upload of transmitter CSV and update internal DataFrame.

        @param change: {dict} The change event payload from the file upload widget.
        """
        self.out_dl_tx.clear_output()
        if not self.upload_tx.value:
            with self.out_dl_tx:
                print("No transmitters file.")
            self.df_tx = None
            self.update_button_state()
            return

        self.df_tx = self._load_csv_widget(
            upload=self.upload_tx,
            required=[
                "transmitter name",
                "transmitter longitude",
                "transmitter latitude",
                "transmitter height",
                "azimuth",
                "downtilt",
                "frequency",
                "emitting power"
            ],
            float_cols=[
                "transmitter longitude", "transmitter latitude",
                "transmitter height", "azimuth", "downtilt",
                "frequency", "emitting power"
            ],
            lon_col="transmitter longitude",
            lat_col="transmitter latitude",
            out_widget=self.out_dl_tx
        )
        self.update_button_state()


    # ----------------------------------------------------------
    #               RECEIVERS MANAGEMENT
    # ----------------------------------------------------------
    def update_rx_visibility(self, *_) -> None:
        """
        Toggle receiver input containers depending on radio selection.
        """
        if self.radio_rx.value == "csv":
            self.rx_dl_container.layout.display = "block"
            self.rx_search_container.layout.display = "none"
        else:
            self.rx_dl_container.layout.display = "none"
            self.rx_search_container.layout.display = "block"
        self.update_button_state()


    def _handle_upload_rx(self, change: dict) -> None:
        """
        Handle upload of receiver CSV and update internal DataFrame.

        @param change: {dict} The change event payload from the file upload widget.
        """
        self.out_dl_rx.clear_output()

        if not self.upload_rx.value:
            with self.out_dl_rx:
                print("No receivers file.")
            self.df_rx = None
            self.update_button_state()
            return

        self.df_rx = self._load_csv_widget(
            upload=self.upload_rx,
            required=[
                "receiver name",
                "receiver longitude",
                "receiver latitude",
                "receiver height"
            ],
            float_cols=[
                "receiver longitude",
                "receiver latitude",
                "receiver height"
            ],
            lon_col="receiver longitude",
            lat_col="receiver latitude",
            out_widget=self.out_dl_rx
        )
        self.update_button_state()


    # ----------------------------------------------------------
    #               CSV GENERIC LOADER
    # ----------------------------------------------------------
    def _load_csv_widget(
        self,
        upload: widgets.FileUpload,
        required: list[str],
        float_cols: list[str],
        lon_col: str,
        lat_col: str,
        out_widget: widgets.Output
    ) -> Optional[pd.DataFrame]:
        """
        Load a CSV file from an ipywidgets.FileUpload widget and validate it.

        @param upload: {widgets.FileUpload} The upload widget holding the file content.
        @param required: {list[str]} Required column names.
        @param float_cols: {list[str]} Columns expected to be numeric (float-castable).
        @param lon_col: {str} Name of the longitude column to validate range.
        @param lat_col: {str} Name of the latitude column to validate range.
        @param out_widget: {widgets.Output} Output widget to display messages.
        @return: {Optional[pd.DataFrame]} The validated DataFrame, or None if validation fails.
        """
        # JupyterLab = tuple ; Jupyter Notebook = dict
        files = upload.value
        if isinstance(files, tuple):
            fi = files[0]
            filename = fi["name"]
            content = fi["content"]
        else:
            filename = next(iter(files))
            fi = files[filename]
            content = fi["content"]

        try:
            df = pd.read_csv(io.BytesIO(content), sep=";")
        except Exception as e:
            with out_widget:
                print(f"Error reading file: {e}")
            return None

        # Validate
        errors = self._validate_dataframe(df, required, float_cols, lon_col, lat_col)
        if errors:
            with out_widget:
                html = widgets.HTML("".join(
                    f"<b style='color:#b00020'>{err}</b><br>" for err in errors
                ))
                display(html)
            return None

        # OK
        with out_widget:
            print(f"File loaded: {filename}")
            display(df.head())
        return df


    def _validate_dataframe(
        self,
        df: pd.DataFrame,
        required: list[str],
        float_cols: list[str],
        lon_col: str,
        lat_col: str
    ) -> list[str]:
        """
        Validate CSV structure and content.

        @param df: {pd.DataFrame} The loaded DataFrame to validate.
        @param required: {list[str]} Required column names.
        @param float_cols: {list[str]} Columns expected to be numeric (float-castable).
        @param lon_col: {str} Longitude column name for range checks.
        @param lat_col: {str} Latitude column name for range checks.
        @return: {list[str]} List of validation error messages; empty if valid.
        """
        errors = []

        missing = [c for c in required if c not in df.columns]
        if missing:
            errors.append("Missing required columns:")
            errors.extend(f"  - {c}" for c in missing)
            return errors

        for c in float_cols:
            try:
                df[c].astype(float)
            except Exception:
                errors.append(f"Column '{c}' contains invalid numeric values.")

        if lon_col and not df[lon_col].between(-180, 180).all():
            errors.append(f"Invalid longitude values in '{lon_col}'.")

        if lat_col and not df[lat_col].between(-90, 90).all():
            errors.append(f"Invalid latitude values in '{lat_col}'.")

        for c in required:
            if df[c].isna().any():
                errors.append(f"Column '{c}' contains missing values.")

        return errors


    # ----------------------------------------------------------
    #               RECEIVER ADDRESS SEARCH
    # ----------------------------------------------------------
    def _on_text_change_rx(self, change: dict) -> None:
        """
        Debounced handler for receiver address text changes.

        @param change: {dict} The event payload containing the new text value under key 'new'.
        """
        query = change["new"]
        self.df_rx = None
        self.out_search_rx.clear_output()
        self.update_button_state()

        if self._debounce_task and not self._debounce_task.done():
            self._debounce_task.cancel()

        self._debounce_task = asyncio.create_task(self._debounce_wrapper(query))


    async def _debounce_wrapper(self, query: str) -> None:
        """
        Schedule the debounced fetch with a delay to reduce API calls.

        @param query: {str} The current text input to be searched.
        """
        try:
            await asyncio.sleep(0.5)
            await self._debounced_fetch(query)
        except asyncio.CancelledError:
            pass


    async def _debounced_fetch(self, query: str) -> None:
        """
        Perform the Nominatim lookup after debouncing and rate-limiting.

        @param query: {str} The user's address query.
        """
        query = query.strip()
        if len(query) < 3:
            self._set_suggestions([])
            self.status.value = "<i>Keep typing (min 3 chars)…</i>"
            return

        now = time.time()
        wait = (self._last_request + self.min_delay_seconds) - now
        if wait > 0:
            await asyncio.sleep(wait)

        self.status.value = "<i>Searching…</i>"

        try:
            results = self._nominatim_search(query)
            self._last_request = time.time()

            cleaned = [{
                "display_name": item.get("display_name"),
                "lat": float(item["lat"]),
                "lon": float(item["lon"]),
                "type": item.get("type"),
                "class": item.get("class"),
                "address": item.get("address", {})
            } for item in results]

            self._set_suggestions(cleaned)
            self.status.value = f"<i>{len(cleaned)} suggestion(s) found.</i>"

        except Exception as e:
            self._set_suggestions([])
            self.status.value = f"<b style='color:#b00020'>Error:</b> {e}"


    def _nominatim_search(self, query: str) -> list[dict]:
        """
        Send a Nominatim search request and return parsed results.

        @param query: {str} Free-text address or place query.
        @return: {list[dict]} Raw result items as returned by the Nominatim API.
        """
        params = {
            "q": query, "format": "jsonv2",
            "limit": 5, "addressdetails": 1
        }
        headers = {"User-Agent": "CoverageUI BWS Notebook"}

        r = requests.get(NOMINATIM_URL, params=params, headers=headers, timeout=15)
        r.raise_for_status()
        return r.json()


    def _set_suggestions(self, items: list[dict]) -> None:
        """
        Populate the suggestions widget with formatted entries.

        @param items: {list[dict]} Cleaned Nominatim results including display_name, lat, lon.
        """
        if not items:
            self.suggestions_rx.options = []
            self.suggestions_rx.layout.display = "none"
            return

        self.suggestions_rx.layout.display = "block"
        self.suggestions_rx.options = [(i["display_name"], i) for i in items]
        self.suggestions_rx.value = None


    # ----------------------------------------------------------
    #               SELECTION FROM ADDRESS RESULTS
    # ----------------------------------------------------------
    def _on_select_rx(self, change: dict) -> None:
        """
        Handle selection from Nominatim suggestions and create a one-row Rx DataFrame.

        @param change: {dict} The event payload; the new selection is under key 'new'.
        """
        val = change["new"]
        if not val:
            return

        lat, lon = val["lat"], val["lon"]
        name = self._normalize_receiver_name(val["display_name"])

        self.df_rx = pd.DataFrame([{
            "receiver name": name,
            "receiver longitude": lon,
            "receiver latitude": lat,
            "receiver height": RECEPTION_HEIGHT
        }])

        self.out_search_rx.clear_output()
        with self.out_search_rx:
            print("✅ Selection:")
            print(name)
            print("")
            print("Coordinates:")
            print(f"Latitude  : {lat}")
            print(f"Longitude : {lon}")

        self.update_button_state()


    def _normalize_receiver_name(self, raw: str) -> str:
        """
        Normalize a raw address string into a safe receiver name (<= 100 chars).

        @param raw: {str} Raw address text (e.g., from Nominatim 'display_name').
        @return: {str} Normalized receiver name using lowercase and underscores.
        """
        text = " ".join(raw.split(",")[:3])
        text = text.lower()
        text = re.sub(r"[^a-z0-9]+", "_", text)
        text = re.sub(r"_+", "_", text).strip("_")
        if len(text) > 100:
            cut = text[:100]
            if "_" in cut:
                cut = cut[:cut.rfind("_")]
            text = cut
        return text


    # ----------------------------------------------------------
    #               START BUTTON MANAGEMENT
    # ----------------------------------------------------------
    def update_button_state(self, *_) -> None:
        """
        Enable/disable the Run button depending on required inputs availability.
        """
        ready = (
            isinstance(self.df_tx, pd.DataFrame)
            and isinstance(self.df_rx, pd.DataFrame)
            and self.dropdown_model.value is not None
            and self.dropdown_antenna.value is not None
        )
        self.btn_run.disabled = not ready


    # ----------------------------------------------------------
    #          BUILD A GEODESIC BUFFER AROUND A RX POINT
    # ----------------------------------------------------------
    def geodesic_buffer(self, lon: float, lat: float, n: int = 180) -> Polygon:
        """
        Build a WGS84 geodesic buffer (circle) centered on (lon, lat).

        @param lon: {float} Buffer center longitude in decimal degrees.
        @param lat: {float} Buffer center latitude in decimal degrees.
        @param n: {int} Number of azimuth samples (higher = smoother circle).
        @return: {Polygon} Shapely polygon approximating the buffer.
        """
        lons, lats = [], []
        geod = Geod(ellps="WGS84")

        for az in range(0, 360, 360 // n):
            lon2, lat2, _ = geod.fwd(lon, lat, az, RECEIVER_BUFFER_RADIUS_M)
            lons.append(lon2)
            lats.append(lat2)

        return Polygon(zip(lons, lats))


    # ----------------------------------------------------------
    #         FILTER TX/RX PAIRS BASED ON GEODESIC BUFFER
    # ----------------------------------------------------------
    def build_filtered_network(self, df_tx: pd.DataFrame, df_rx: pd.DataFrame) -> pd.DataFrame:
        """
        Keep only (tx, rx) pairs where the transmitter lies inside the Rx buffer.

        @param df_tx: {pd.DataFrame} Transmitters table.
        @param df_rx: {pd.DataFrame} Receivers table.
        @return: {pd.DataFrame} Flat table of (tx, rx) pairs passing the spatial filter.
        """
        rows = []

        for _, rx in df_rx.iterrows():
            buf = self.geodesic_buffer(
                rx["receiver longitude"],
                rx["receiver latitude"]
            )

            for _, tx in df_tx.iterrows():
                pt = Point(tx["transmitter longitude"], tx["transmitter latitude"])

                if buf.contains(pt):
                    rows.append({
                        "transmitter id": tx["transmitter id"],
                        "transmitter name": tx.get("transmitter name", None),
                        "transmitter longitude": tx["transmitter longitude"],
                        "transmitter latitude": tx["transmitter latitude"],
                        "transmitter height": tx["transmitter height"],
                        "azimuth": tx["azimuth"],
                        "downtilt": tx["downtilt"],
                        "frequency": tx["frequency"],
                        "emitting power": tx["emitting power"],

                        "receiver name": rx["receiver name"],
                        "receiver longitude": rx["receiver longitude"],
                        "receiver latitude": rx["receiver latitude"],
                        "receiver height": rx["receiver height"],
                    })

        return pd.DataFrame(rows)


    # ----------------------------------------------------------
    #         CHECK THAT EACH RECEIVER HAS AT LEAST ONE TX
    # ----------------------------------------------------------
    def check_missing_receivers(self, df_rx: pd.DataFrame, df_network: pd.DataFrame) -> None:
        """
        Warn if a receiver has no transmitter within the configured buffer radius.

        @param df_rx: {pd.DataFrame} Input receivers table.
        @param df_network: {pd.DataFrame} Filtered (tx, rx) pairs produced by `build_filtered_network`.
        """
        rx_in_network = set(df_network["receiver name"].unique())
        rx_expected = set(df_rx["receiver name"].unique())

        missing = rx_expected - rx_in_network

        with self.out_status:
            for rx in missing:
                print(
                    f"⚠️ Receiver '{rx}' has no transmitter "
                    f"within {RECEIVER_BUFFER_RADIUS_M/1000:.1f} km."
                )


    # ----------------------------------------------------------
    #               BWS API — SESSION
    # ----------------------------------------------------------
    def create_session(self) -> dict:
        """
        Create a new BWS session and return its details.

        @return: {dict} The created session payload as returned by the BWS API.
        """
        session = {
            "uuid": str(self.SESSION_UUID),
            "name": "session_notebook_mp2mp",
            "description": "Session sample MP to MP from Jupyter Notebook"
        }

        response = call_request(
            method="POST",
            url=f"{BWS_API_URL}/sessions",
            authentication_data=AUTHENTICATION,
            json_content=session
        )

        result = response.json()
        if response.status_code != 201:
            with self.out_status:
                print(f"❌ Error creating session: {result['message']}")
        return result


    # ----------------------------------------------------------
    #               BWS API — SIMULATION CREATION
    # ----------------------------------------------------------
    def create_simulation(self, df_network: pd.DataFrame, antenna_uuid: str, model_uuid: str) -> dict:
        """
        Build and submit the MP2MP simulation request to the BWS server.

        @param df_network: {pd.DataFrame} Filtered (tx, rx) pairs with radio params.
        @param antenna_uuid: {str} Antenna UUID to attach to the base station.
        @param model_uuid: {str} Propagation model UUID to be used.
        @return: {dict} The created simulation payload as returned by the BWS API.
        """
        propagation_list = []

        for _, net in df_network.iterrows():

            base_station = {
                "x": float(net["transmitter longitude"]),
                "y": float(net["transmitter latitude"]),
                "z": float(net["transmitter height"]),
                "epsgCode": 4326,
                "zmeaning": "ZMEANING_GROUND",
                "azimuth": float(net["azimuth"]),
                "downtilt": float(net["downtilt"]),
                "carrierFrequency": float(net["frequency"]),
                "sessionUuid": str(self.SESSION_UUID),
                "name": net["transmitter name"],
                "networkId": net["transmitter id"],
                "transmitPower": float(net["emitting power"]),
                "antennaUuid": antenna_uuid
            }

            ue = {
                "sessionUuid": str(self.SESSION_UUID),
                "type": "POINT",
                "name": net["receiver name"],
                "heights": [net["receiver height"]],
                "coordinates": {
                    "x": net["receiver longitude"],
                    "y": net["receiver latitude"],
                    "epsgCode": 4326
                }
            }

            # Check for existing propagation scenario
            for p in propagation_list:
                if p["baseStation"]["networkId"] == base_station["networkId"]:
                    p["userEquipments"].append(ue)
                    break
            else:
                propagation_list.append({
                    "baseStation": base_station,
                    "userEquipments": [ue],
                    "propagationModelUuid": model_uuid
                })

        simulation_request = {
            "uuid": str(self.SIMULATION_UUID),
            "name": "session_sample_mp2mp_notebook_simulation",
            "calculationSessionUuid": str(self.SESSION_UUID),
            "propagationRequest": {
                "propagationScenarios": propagation_list,
                "resultTypes": ["RECEIVED_POWER"],
                "zmeaning": "ZMEANING_GROUND"
            }
        }

        multipart = [
            ("json", (None, json.dumps(simulation_request), "application/json"))
        ]

        response = call_request(
            method="POST",
            url=f"{BWS_API_URL}/simulations",
            authentication_data=AUTHENTICATION,
            files=multipart
        )

        result = response.json()
        if response.status_code != 201:
            with self.out_status:
                print(f"❌ Error creating simulation: {result['message']}")

        return result


    # ----------------------------------------------------------
    #               BWS API — WAIT FOR SIMULATION
    # ----------------------------------------------------------
    def wait_for_simulation(self, poll_seconds: int = 5) -> None:
        """
        Poll the simulation status periodically and update the progress bar.

        @param poll_seconds: {int} Poll interval in seconds (default: 5).
        """
        with self.out_status:
            progress = widgets.FloatProgress(min=0, max=100)
            status = widgets.HTML("<b>Waiting…</b>")
            display(widgets.VBox([progress, status]))

        last_prg = None
        while True:
            time.sleep(poll_seconds)

            response = call_request(
                method="GET",
                url=f"{BWS_API_URL}/simulations/{self.SIMULATION_UUID}/status",
                authentication_data=AUTHENTICATION
            ).json()

            prg = float(response.get("progress", 0) or 0)
            state = (response.get("state") or "").upper()

            if prg != last_prg:
                progress.value = prg
                last_prg = prg
                status.value = f"State: {state} — Progress: {prg:.1f}%"

            if state == "DONE":
                progress.value = 100
                progress.bar_style = "success"
                status.value = "<b>Simulation finished successfully.</b>"
                break

            if state == "ERROR":
                progress.bar_style = "danger"
                status.value = "<b>Simulation failed.</b>"
                break


    # ----------------------------------------------------------
    #               BWS API — DOWNLOAD RESULTS
    # ----------------------------------------------------------
    def download_results(self) -> list[dict]:
        """
        Download all simulation result files to a temp folder.

        @return: {list[dict]} List of dicts with keys: 'name' (basename) and 'path' (absolute path).
        """
        results_path = Path("/tmp/results")
        if results_path.exists():
            shutil.rmtree(results_path)
        results_path.mkdir(parents=True)

        response = call_request(
            method="GET",
            url=f"{BWS_API_URL}/simulations/{self.SIMULATION_UUID}/results",
            authentication_data=AUTHENTICATION
        )
        results = response.json()

        output = []

        for r in results:
            tiff = call_request(
                method="GET",
                url=f"{BWS_DL_URL}/results/{r['uuid']}/download",
                authentication_data=AUTHENTICATION
            )

            file_path = results_path / r["fileName"]
            with open(file_path, "wb") as f:
                f.write(tiff.content)

            output.append({
                "name": r["fileName"].split(".")[0],
                "path": str(file_path)
            })

        return output


    # ----------------------------------------------------------
    #           BUILD MP2MP MATRIX (JSON → DataFrame)
    # ----------------------------------------------------------
    def generate_mp2mp_matrix(self, results: list[dict], metric_name: str = "received_power") -> pd.DataFrame:
        """
        Convert MP2MP JSON result files into a receiver x transmitter matrix.

        @param results: {list[dict]} File descriptors with 'path' pointing to local JSON result files.
        @param metric_name: {str} Metric key to extract (default: 'received_power').
        @return: {pd.DataFrame} Wide matrix with receivers as rows and TX_<metric> columns.
        """
        all_rows = []

        for res in results:
            file_path = Path(res["path"])
            if not file_path.exists():
                with self.out_status:
                    print(f"❌ File not found: {file_path}")
                continue

            try:
                with open(file_path, "r", encoding="utf-8") as f:
                    data = json.load(f)
                all_rows.extend(extract_rows_from_json(data, metric_name=metric_name))
            except Exception as e:
                with self.out_status:
                    print(f"❌ Cannot read {file_path}: {e}")
                continue

        df_long = pd.DataFrame(all_rows)
        if df_long.empty:
            return pd.DataFrame()

        df = df_long.pivot_table(
            index="receiver",
            columns="transmitter",
            values=metric_name,
            aggfunc="first"
        )

        df.columns = [f"{c}_{metric_name}" for c in df.columns]
        df = df.sort_index()

        return df


    # ----------------------------------------------------------
    #                     GENERATE KPI TABLE
    # ----------------------------------------------------------
    def generate_kpi(self, df_matrix: pd.DataFrame, metric_name: str = "received_power") -> pd.DataFrame:
        """
        Compute KPIs per receiver (best signal, best server, throughput).

        @param df_matrix: {pd.DataFrame} Receiver x Transmitter matrix with '<tx>_<metric>' columns.
        @param metric_name: {str} Metric suffix used in matrix column names (default: 'received_power').
        @return: {pd.DataFrame} KPI table with columns: Rx name, Best signal, Best server, Throughput.
        """
        mapping = pd.read_csv("mapping_power_throughput.csv", sep=";")

        kpi_rows = []

        for rx_name, row in df_matrix.iterrows():
            try:
                kpi_rows.append(self._compute_kpi_row(rx_name, row, mapping, metric_name))
            except Exception as e:
                with self.out_status:
                    print(f"❌ KPI error for {rx_name}: {e}")

        return pd.DataFrame(kpi_rows)


    def _compute_kpi_row(
        self,
        rx_name: str,
        row: pd.Series,
        mapping: pd.DataFrame,
        metric_name: str
    ) -> dict[str, Any]:
        """
        Compute KPIs for a single receiver row.

        @param rx_name: {str} Receiver name (row index).
        @param row: {pd.Series} Row with TX_<metric> columns.
        @param mapping: {pd.DataFrame} Power→throughput lookup table.
        @param metric_name: {str} Metric suffix used in column names.
        @return: {dict[str, Any]} KPI record with Rx name, best signal, best server, throughput.
        """
        # Best signal
        best_signal = row.max(skipna=True)

        # Best server
        best_site = row.idxmax(skipna=True).replace(f"_{metric_name}", "")

        # Throughput mapping
        eligible = mapping[mapping["power"] <= best_signal]
        throughput = eligible.iloc[-1]["throughput"] if not eligible.empty else np.nan

        return {
            "Rx name": rx_name,
            "Best signal (dBm)": best_signal,
            "Best server": best_site,
            "Throughput (MBps)": throughput
        }


    # ----------------------------------------------------------
    #               RUN WORKFLOW
    # ----------------------------------------------------------
    def on_run_clicked(self, b: widgets.Button) -> None:
        """
        Execute the full workflow: validation → BWS session/simulation → wait → download → KPIs.

        @param b: {widgets.Button} The click event source (unused; required by ipywidgets).
        """
        self.out_status.clear_output()

        # Basic validation
        if self.df_tx is None or self.df_rx is None:
            with self.out_status:
                print("❌ Transmitters and receivers must be loaded.")
            return

        if self.dropdown_model.value is None:
            with self.out_status:
                print("❌ Propagation model missing.")
            return

        if self.dropdown_antenna.value is None:
            with self.out_status:
                print("❌ Antenna missing.")
            return

        # Prepare network
        df_tx = self.df_tx.copy()
        df_tx["transmitter id"] = range(1, len(df_tx) + 1)
        df_network = self.build_filtered_network(df_tx, self.df_rx)

        if df_network.empty:
            with self.out_status:
                print("❌ No transmitter is within range of any receiver.")
                print("You can change the buffer radius size (constant RECEIVER_BUFFER_RADIUS_M).")
            return

        self.check_missing_receivers(self.df_rx, df_network)

        # RUN WORKFLOW
        self.SESSION_UUID = uuid.uuid4()
        self.SIMULATION_UUID = uuid.uuid4()

        with self.out_status:
            print("📡 Creating session...")
        self.create_session()

        with self.out_status:
            print("📡 Creating simulation...")
        self.create_simulation(df_network, self.dropdown_antenna.value, self.dropdown_model.value)

        with self.out_status:
            print("⏳ Wait for the simulation calculation...")
        self.wait_for_simulation()

        with self.out_status:
            print("📥 Downloading results…")
        results = self.download_results()

        with self.out_status:
            print("📊 Building matrix…")
        df_matrix = self.generate_mp2mp_matrix(results)
        with self.out_status:
            print("✨ Results matrix:")
            display(df_matrix)

        with self.out_status:
            print("📈 Computing KPI…")
        df_kpi = self.generate_kpi(df_matrix)
        with self.out_status:
            print("✨ KPI:")
            display(df_kpi)

# %% [markdown]
# ## UI Display

# %%
ui = CoverageUI()
display(ui.root)
